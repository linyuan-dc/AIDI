# %%
import visnews
# poll news once
visnews.pollonce()
# Out:
# Nov 15, 2020, 10:30 ET:
# Cleveland Clinic-Led Trial Finds High Doses of a Prescription Fish Oil Do Not Reduce Major Cardiac Events in High-Risk Patients
# Nov 15, 2020, 08:35 ET:
# Terceiro CIIE concluído com assinatura de negócios pretendidos para o próximo ano de US$ 72,6 bilhões
# Nov 15, 2020, 08:31 ET:
# I-nvention presenta The Cone+ con un filtro de carbono en forma de cono
# Nov 15, 2020, 08:23 ET:
# Le CHMP a adopté un avis positif pour ELZONRIS (tagraxofusp), pour le traitement du néoplasme des cellules dendritiques plasmacétoïdes blastiques (NCDPB)
# Nov 15, 2020, 00:00 ET:
# British High Commissioner Dr. Christian Turner Inaugurates Robot-Operated Covid-19 Testing Lab in Islamabad
# Nov 14, 2020, 20:38 ET:
# CGTN: Yangtze River Economic Belt to power China's high-quality development
# Nov 14, 2020, 20:30 ET:
# GO2 Foundation for Lung Cancer Recognizes the Lung Cancer Community at Simply the Best XV Virtual Gala
# Nov 14, 2020, 19:00 ET:
# ...

# %%
import visnews
# poll the news for every 10 seconds
visnews.pollnews(10)
